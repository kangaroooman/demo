# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Roman Isaenkov**
#
# PhD Student

# %% [markdown]
# I'm interested in data science because it is a science about the data. We can use it in many ways to help people make better data based desicions

# %% [markdown]
# ### In the next cell we'll compute the result of 1 + 1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# This is a table
#
#
# | a      | b |
# | ----------- | ----------- |
# | 11      | 12       |
# | 21   | 22        |
#
#
# Here is a rule
# _____________________________________
#
# Here goes a list:
# * a
# * b
# * c
